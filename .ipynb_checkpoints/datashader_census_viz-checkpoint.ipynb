# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = gpd.read_file('sumatera_point.shp')
df2 = gpd.read_file('jawa_bali_point.shp')
df3 = gpd.read_file('kalimantan_point.shp')
df4 = gpd.read_file('sulawesi_point.shp')
df5 = gpd.read_file('nusa_point.shp')
df6 = gpd.read_file('papua_point.shp')

# %%
print( df1.shape, df2.shape, df3.shape, df4.shape, df5.shape, df6.shape)
# Out:
# (40867, 2) (102786, 2) (43322, 2) (16517, 2) (9168, 2) (8689, 2)

# %%
df = df1.append(df2)
df = df.append(df3)
df = df.append(df4)
df = df.append(df5)
df = df.append(df6)
df.shape
# Out:
# (221349, 2)

# %%
# df.to_file('point_penduduk.shp')

# %% [markdown]
# Population of indonesia estimated until 261 million, but i generate the data base on population density not base on amount of population. so one point could represents 1000 people and soon.

# %%
df.plot()

# %%
import datashader as ds
import datashader.transfer_functions as tf
import dask.dataframe as dd
import numpy as np
import pandas as pd

# %%
indo = ((94.43, 142.30) , (-10.45 , 6.28))

# %%
df_ = pd.DataFrame()
df_['LONGITUDE'] = df.geometry.x
df_['LATITUDE'] = df.geometry.y

# %%
from datashader.utils import lnglat_to_meters as webm
x_range,y_range = [list(r) for r in webm(*indo)]

# %%
plot_width  = int(900)
plot_height = int(plot_width*5.0/12)

# %%
background = "black"

# %%
from functools import partial
from datashader.utils import export_image
from datashader.colors import colormap_select, Greys9
from IPython.core.display import HTML, display

export = partial(export_image, background = background, export_path="export")
cm = partial(colormap_select, reverse=(background!="black"))

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%time
cvs = ds.Canvas(plot_width, plot_height, (*indo))
agg = cvs.points(df_, 'LONGITUDE', 'LATITUDE')
# Out:
# Wall time: 3 ms

# %%
export(tf.shade(agg, cmap = cm(Greys9,0.25), how='linear'),"census_gray_linear")
# Out:
# <xarray.Image (LATITUDE: 375, LONGITUDE: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * LATITUDE   (LATITUDE) float64 -10.43 -10.38 -10.34 -10.29 -10.25 -10.2 ...
#   * LONGITUDE  (LONGITUDE) float64 94.46 94.51 94.56 94.62 94.67 94.72 94.78 ...

# %%
from colorcet import fire
export(tf.shade(agg, cmap = cm(fire,0.2), how='eq_hist'),"census_ds_fire_eq_hist")
# Out:
# <xarray.Image (LATITUDE: 375, LONGITUDE: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * LATITUDE   (LATITUDE) float64 -10.43 -10.38 -10.34 -10.29 -10.25 -10.2 ...
#   * LONGITUDE  (LONGITUDE) float64 94.46 94.51 94.56 94.62 94.67 94.72 94.78 ...

# %%
from datashader.colors import viridis
export(tf.shade(agg, cmap=cm(viridis), how='eq_hist'),"census_viridis_eq_hist")
# Out:
# <xarray.Image (LATITUDE: 375, LONGITUDE: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * LATITUDE   (LATITUDE) float64 -10.43 -10.38 -10.34 -10.29 -10.25 -10.2 ...
#   * LONGITUDE  (LONGITUDE) float64 94.46 94.51 94.56 94.62 94.67 94.72 94.78 ...

# %% [markdown]
# Visualization using redhot style show where the most dense area, red color can be indicated as capital city. For example Jakarta, Medan, Bandung

# %%
grays2 = cm([(i,i,i) for i in np.linspace(0,255,99)])
grays2 += ["red"]
export(tf.shade(agg, cmap = grays2, how='eq_hist'),"census_gray_redhot1_eq_hist")
# Out:
# <xarray.Image (LATITUDE: 375, LONGITUDE: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * LATITUDE   (LATITUDE) float64 -10.43 -10.38 -10.34 -10.29 -10.25 -10.2 ...
#   * LONGITUDE  (LONGITUDE) float64 94.46 94.51 94.56 94.62 94.67 94.72 94.78 ...
